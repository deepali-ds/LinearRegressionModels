# %%
import pandas as pd

# %%
#!pip install icevision[all]
#!pip install torchvision==0.8.1
#!pip install torchtext==0.8
#!pip install torch==1.7
#!pip install pyyaml==5.4
#!pip install folium==0.2.1

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# path to the shortcut
root = "./drive/MyDrive/"

import os
data = os.path.join(root, "AI for Wind Energy share", "Data")
dataset_a = os.path.join(data, "Dataset A ", "datasetA")
dataset_a_T = os.path.join(data,"Dataset A ", "datasetA_T")

# %%
def load_data(dataset, case, number, file_name):
    data = pd.read_csv(f"{dataset}/{case}/{case}_{number}/{file_name}", skiprows=22, delimiter="\t")
    print(data.columns)
    print(data.describe)
    return data

#@title Create Dataset
case = 'Case_R_(+00)' #@param ['Case_A_(+00)', 'Case_A_(+05)', 'Case_A_(+10)', 'Case_A_(+15)', 'Case_A_(+20)', 'Case_A_(+25)', 'Case_A_(+30)', 'Case_A_(+35)', 'Case_A_(+40)', 'Case_A_(-05)', 'Case_A_(-10)', 'Case_A_(-15)', 'Case_B_(+00)', 'Case_B_(+05)', 'Case_B_(+10)', 'Case_B_(+15)', 'Case_B_(+20)', 'Case_B_(+25)', 'Case_B_(+30)', 'Case_B_(+35)', 'Case_B_(+40)', 'Case_B_(-05)', 'Case_B_(-10)', 'Case_B_(-15)', 'Case_C_(+00)', 'Case_C_(+05)', 'Case_C_(+10)', 'Case_C_(+15)', 'Case_C_(+20)', 'Case_C_(+25)', 'Case_C_(+30)', 'Case_C_(+35)', 'Case_C_(+40)', 'Case_C_(-05)', 'Case_C_(-10)', 'Case_C_(-15)', 'Case_D_(+00)', 'Case_D_(+05)', 'Case_D_(+10)', 'Case_D_(+15)', 'Case_D_(+20)', 'Case_D_(+25)', 'Case_D_(+30)', 'Case_D_(+35)', 'Case_D_(+40)', 'Case_D_(-05)', 'Case_D_(-10)', 'Case_D_(-15)', 'Case_E_(+00)', 'Case_E_(+05)', 'Case_E_(+10)', 'Case_E_(+15)', 'Case_E_(+20)', 'Case_E_(+25)', 'Case_E_(+30)', 'Case_E_(+35)', 'Case_E_(+40)', 'Case_E_(-05)', 'Case_E_(-10)', 'Case_E_(-15)', 'Case_F_(+00)', 'Case_F_(+05)', 'Case_F_(+10)', 'Case_F_(+15)', 'Case_F_(+20)', 'Case_F_(+25)', 'Case_F_(+30)', 'Case_F_(+35)', 'Case_F_(+40)', 'Case_F_(-05)', 'Case_F_(-10)', 'Case_F_(-15)', 'Case_G_(+00)', 'Case_G_(+05)', 'Case_G_(+10)', 'Case_G_(+15)', 'Case_G_(+20)', 'Case_G_(+25)', 'Case_G_(+30)', 'Case_G_(+35)', 'Case_G_(+40)', 'Case_G_(-05)', 'Case_G_(-10)', 'Case_G_(-15)', 'Case_H_(+00)', 'Case_H_(+05)', 'Case_H_(+10)', 'Case_H_(+15)', 'Case_H_(+20)', 'Case_H_(+25)', 'Case_H_(+30)', 'Case_H_(+35)', 'Case_H_(+40)', 'Case_H_(-05)', 'Case_H_(-10)', 'Case_H_(-15)', 'Case_I_(+00)', 'Case_I_(+05)', 'Case_I_(+10)', 'Case_I_(+15)', 'Case_I_(+20)', 'Case_I_(+25)', 'Case_I_(+30)', 'Case_I_(+35)', 'Case_I_(+40)', 'Case_I_(-05)', 'Case_I_(-10)', 'Case_I_(-15)', 'Case_J_(+00)', 'Case_J_(+05)', 'Case_J_(+10)', 'Case_J_(+15)', 'Case_J_(+20)', 'Case_J_(+25)', 'Case_J_(+30)', 'Case_J_(+35)', 'Case_J_(+40)', 'Case_J_(-05)', 'Case_J_(-10)', 'Case_J_(-15)', 'Case_K_(+00)', 'Case_K_(+05)', 'Case_K_(+10)', 'Case_K_(+15)', 'Case_K_(+20)', 'Case_K_(+25)', 'Case_K_(+30)', 'Case_K_(+35)', 'Case_K_(+40)', 'Case_K_(-05)', 'Case_K_(-10)', 'Case_K_(-15)', 'Case_L_(+00)', 'Case_L_(+05)', 'Case_L_(+10)', 'Case_L_(+15)', 'Case_L_(+20)', 'Case_L_(+25)', 'Case_L_(+30)', 'Case_L_(+35)', 'Case_L_(+40)', 'Case_L_(-05)', 'Case_L_(-10)', 'Case_L_(-15)', 'Case_R_(+00)', 'Case_R_(+05)', 'Case_R_(+10)', 'Case_R_(+15)', 'Case_R_(+20)', 'Case_R_(+25)', 'Case_R_(+30)', 'Case_R_(+35)', 'Case_R_(+40)', 'Case_R_(-05)', 'Case_R_(-10)', 'Case_R_(-15)']
number = "1" #@param [1, 2]
mode = 'white_noise_2' #@param ['sine_sweep','white_noise_1','white_noise_2','white_noise_3','white_noise_4','white_noise_5']
sensors = 'accelerometers' #@param ['accelerometers', 'humidities', 'temperatures', 'rosette_A', 'rosette_B', 'rosette_C', 'force', 'others']

description = os.path.join(dataset_a,
                            case,
                            case + "_" + number,
                            "description.txt")

with open(description) as f:
    print(f.read())
try:
    data = load_data(dataset_a, case, number, mode + ".lvm")

except:
    import re
    folder_path = os.path.join(dataset_a,
                              case,
                              case + "_" + number)
    files = os.listdir(folder_path)
    mode = [re.findall("sine_sweep[\w_]*", file_name) for file_name in files if len(re.findall("sine_sweep[/w_.]*", file_name)) > 0][0][0]
    data = load_data(dataset_a, case, number, mode + ".lvm")

data = data.drop(['Comment'], axis=1)
# data = data.set_index('X_Value')
# Out:
# Date:			2017_02_15
# Case label:    		R
# Temperature:	   	+00
# Sensor scheme:     	1
# Relative humidity:	60%
#
# Index(['X_Value', 'Ch1', 'Ch2', 'Ch3', 'Ch4', 'Ch5', 'Ch6', 'Ch7', 'Ch8',
#        'K7861_H', 'K7862_H', 'K7861_T', 'K7862_T', 'force', 'Strain_1',
#        'Strain_2', 'Strain_3_rosette_A', 'Strain_4_rosette_B',
#        'Strain_5_rosette_C', 'Strain_6_1', 'Strain_7_1', 'Strain_8',
#        'Strain_9_1_rosette_A', 'Strain_10_1_rosette_B',
#        'Strain_11_1_rosette_C', 'Strain_12_rosette_A', 'Strain_13_rosette_B',
#        'Strain_14_rosette_C', 'Strain_15_1', 'Strain_16_temp_comp',
#        'Strain_17_rosette_A', 'Strain_18_rosette_B', 'Strain_19_rosette_C',
#        'Strain_20_rosette_A', 'Strain_21_rosette_B', 'Strain_22_rosette_C',
#        'Strain_23', 'Strain_24', 'Strain_16_temp_comp (Filtered)', 'Comment'],
#       dtype='object')
# <bound method NDFrame.describe of          X_Value       Ch1  ...  Strain_16_temp_comp (Filtered)  Comment
# ...

# %%
data.head(3)
# Out:
#    X_Value       Ch1  ...  Strain_24  Strain_16_temp_comp (Filtered)
# 0   0.0000  0.000912  ...  -0.000007                       -0.000004
# 1   0.0006  0.001595  ...  -0.000007                       -0.000004
# 2   0.0012  0.001099  ...  -0.000007                       -0.000004
#
# [3 rows x 39 columns]

# %%
#! pip install pycaret

# %%
# check version
from pycaret.utils import version
version()
# Out:
# '2.3.5'

# %% [markdown]
# **Initializing setup**

# %%
# initializing  setup
from pycaret.anomaly import *
s = setup(data, session_id = 123, log_experiment=True, experiment_name='anomaly')
# Out:
#                                Description           Value
# 0                               session_id             123
# 1                            Original Data    (209916, 39)
# 2                           Missing Values           False
# 3                         Numeric Features              39
# 4                     Categorical Features               0
# 5                         Ordinal Features           False
# 6                High Cardinality Features           False
# 7                  High Cardinality Method            None
# 8                         Transformed Data    (209916, 39)
# 9                                 CPU Jobs              -1
# 10                                 Use GPU           False
# 11                          Log Experiment            True
# 12                         Experiment Name         anomaly
# 13                                     USI            64d8
# 14                         Imputation Type          simple
# ...

# %% [markdown]
# **Creating model**

# %%
# check list of available models
models()
# Out:
#                                         Name                    Reference
# ID
# abod            Angle-base Outlier Detection        pyod.models.abod.ABOD
# cluster       Clustering-Based Local Outlier      pyod.models.cblof.CBLOF
# cof         Connectivity-Based Local Outlier          pyod.models.cof.COF
# iforest                     Isolation Forest  pyod.models.iforest.IForest
# histogram  Histogram-based Outlier Detection        pyod.models.hbos.HBOS
# knn             K-Nearest Neighbors Detector          pyod.models.knn.KNN
# lof                     Local Outlier Factor          pyod.models.lof.LOF
# svm                   One-class SVM detector      pyod.models.ocsvm.OCSVM
# pca             Principal Component Analysis          pyod.models.pca.PCA
# mcd           Minimum Covariance Determinant          pyod.models.mcd.MCD
# sod               Subspace Outlier Detection          pyod.models.sod.SOD
# sos             Stochastic Outlier Selection          pyod.models.sos.SOS

# %%
# train model
iforest = create_model('iforest')

# %%
# train model
knn = create_model('knn', fraction = 0.1)

# %% [markdown]
# **Assigning labels**

# %%
# Assign labels
iforest_results = assign_model(iforest)
iforest_results.head()
# Out:
#    X_Value       Ch1  ...  Anomaly  Anomaly_Score
# 0   0.0000  0.000912  ...        0      -0.030614
# 1   0.0006  0.001595  ...        0      -0.049330
# 2   0.0012  0.001099  ...        0      -0.038081
# 3   0.0018  0.001625  ...        0      -0.042768
# 4   0.0024  0.001291  ...        0      -0.014892
#
# [5 rows x 41 columns]

# %% [markdown]
# **Analyze the model**

# %%
# Plotting the model
plot_model(iforest)

# %%
plot_model(iforest, plot = 'umap')

# %%
# Plotting the model
plot_model(knn)

# %% [markdown]
# **Predicting the model**

# %%
#Model prediction
iforest_predictions = predict_model(iforest, data=data)
iforest_predictions.head()
# Out:
#    X_Value       Ch1  ...  Anomaly  Anomaly_Score
# 0   0.0000  0.000912  ...        0      -0.030614
# 1   0.0006  0.001595  ...        0      -0.049330
# 2   0.0012  0.001099  ...        0      -0.038081
# 3   0.0018  0.001625  ...        0      -0.042768
# 4   0.0024  0.001291  ...        0      -0.014892
#
# [5 rows x 41 columns]

# %%
# Generate predictions using trained model
knn_predictions = predict_model(knn, data = data)

# %%
knn_predictions
# Out:
#          X_Value       Ch1  ...  Anomaly  Anomaly_Score
# 0         0.0000  0.000912  ...        0       0.011997
# 1         0.0006  0.001595  ...        0       0.012336
# 2         0.0012  0.001099  ...        0       0.012525
# 3         0.0018  0.001625  ...        0       0.012613
# 4         0.0024  0.001291  ...        0       0.012701
# ...          ...       ...  ...      ...            ...
# 209911  125.9466  0.001123  ...        0       0.010060
# 209912  125.9472  0.000160  ...        0       0.012605
# 209913  125.9478  0.001041  ...        0       0.011178
# 209914  125.9484  0.001575  ...        0       0.011479
# 209915  125.9490  0.000140  ...        0       0.013632
#
# [209916 rows x 41 columns]

# %% [markdown]
# **Save and load the model**

# %%
save_model(iforest, model_name='iforest')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='UNSUPERVISED_DUMMY_TARGET',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='most frequent',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None...
#                  ('fix_perfect', 'passthrough'),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
# ...

# %%
loaded_iforest = load_model('iforest')
print(loaded_iforest)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[],
#                                       target='UNSUPERVISED_DUMMY_TARGET',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='most frequent',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None...
#                 ('fix_perfect', 'passthrough'),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
# ...

# %%
from sklearn import set_config
set_config(display='diagram')
loaded_iforest[0]
# Out:
# DataTypes_Auto_infer(categorical_features=[], display_types=True,
#                      features_todrop=[], id_columns=[], ml_usecase='regression',
#                      numerical_features=[], target='UNSUPERVISED_DUMMY_TARGET',
#                      time_features=[])
